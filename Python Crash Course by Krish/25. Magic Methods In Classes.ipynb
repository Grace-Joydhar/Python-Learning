# %% [markdown]
# **if you write dir(variable name) - it will show all the magic methods.**

# %%
class Car():
  def __new__(self, windows, doors, enginetype):
    print("The object has started getting initialized")

  def __init__(self, windows, doors, enginetype):
    self.windows = windows
    self.doors = doors
    self.enginetype = enginetype
  
  def __str__(self):
    return "This object has been initialized"

  def __sizeof__(self):
    return "This displays the size of the object"

  def drive(self): #drive is a functionality of the car
    print("The car drives by a person")

# %%
local_car = Car(5,4,'oil')
# Out:
# The object has started getting initialized

# %%
print(local_car)
# Out:
# None

# %%
local_car.__sizeof__() #it will give values as bytes
# Out:
# 16

# %%
dir(local_car)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']
