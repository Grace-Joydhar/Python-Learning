# %% [markdown]
# Class: Class has attributes, properties and functions.
# - Car can think as a class, which has doors, windows, seats etc called as attributes.
# - We driving cars. it could be the functions.
# - Speed of a specific car can think as the attributes.

# %%
class car:
  def __init__(self, window, door, enginetype): #This are the properties inside the car
    self.windows = window #self.windows is a variable
    self.doors = door 
    self.enginetypes = enginetype
  
  def self_driving(self): #This is the method inside the car
    return "This is {} car".format(self.enginetypes)

# %%
#initialize object
car1 = car(4, 5, 'petrol')

# %%
car1.self_driving()
# Out:
# 'This is petrol car'

# %%
car2 =car(3,6, 'oil')

# %%
print(car1.windows)
# Out:
# 4

# %%
print(car2.enginetypes)
# Out:
# oil

# %%
dir(car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'enginetypes',
#  'self_driving',
#  'windows']

# %% [markdown]
# **Normal Way**

# %%
car1.windows = 5
car1.doors = 4

print(car1.windows)
# Out:
# 5
